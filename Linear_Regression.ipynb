# %% [markdown]
# <a href="https://colab.research.google.com/github/Manitchahar/EduGenie/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8-darkgrid")
# from sklearn.datasets import make_regression

# %%
# Data generate X,y

# %%
def generate_dataset(m):
        x = np.random.randn(m)*10
        noise = np.random.randn(m)*12
        print(x.mean(),x.std())
        print(x)
        y =3*x+1+noise
        return x,y

# %%
x, y = generate_dataset(100)
print(x.shape,y.shape)
# Out:
# 0.34741537808453576 11.929946246822459
# [-16.56653008  12.02145808   2.78682496  14.39184096  12.08969077
#   11.31646517 -15.91617492  -3.76133518  -0.28071761 -23.27063117
#   -7.87248427  11.68840186  21.96047187  -0.25164582  -4.31264123
#  -11.58888765  18.74782865  23.19532409  -2.96172745  15.61337215
#   -6.10754457   1.97076242  11.31920102  21.71990411   9.04447275
#   -8.12718659   0.06316592 -19.62994119  12.3964294   -5.9994619
#  -21.03854905  -9.58708798 -11.43413343  -8.86601465  -2.80218108
#  -20.8576772    1.62169275  -1.60147496  20.81705082  -9.06982173
#    4.41610913  -1.19539187  -2.48989671  10.76358631  -9.63594864
#    9.83266262   3.97018872  -4.27283408  21.45502922   8.20348113
#  -15.14697736  16.54724431  -0.81411106  -0.82136374  -0.95850715
#    4.54000849  -5.2503415    8.3978297   -0.07127973   4.03940552
#    5.41435585  -8.96760039   0.42619044   9.56027867  -9.42200046
#   22.31196803  -9.9677291   24.6454624   -2.76965856   2.92032493
# ...

# %%
def plotdata(x,y,color="orange",title = "data"):
    plt.scatter(x,y ,color=color)
    plt.title(title)
    plt.xlabel("x")
    plt.ylabel("y",rotation=0, labelpad=20)
    plt.show()

# %%
plotdata(x,y)

# %%
y.shape, x.shape
# Out:
# ((100,), (100,))

# %%
print(x.mean())
# Out:
# 0.34741537808453576

# %%
# Data normalization
def normalizedata(x):
    x = (x-x.mean())/x.std()
    return x

# %%
plotdata(x,y)
x = normalizedata(x)
plotdata(x,y)
